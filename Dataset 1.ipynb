# %%
import fiftyone as fo
import fiftyone.zoo as foz
from fiftyone import ViewField as F

# %%
dataset = foz.load_zoo_dataset(
    "coco-2017",
    split="train",
    label_types=["detections"],
    classes=["chair", "dining table"],
    max_samples=6000,
)
# Out:
# ...
# Found annotations at '/home/irwan/fiftyone/coco-2017/raw/instances_train2017.json'
# 3852 images found; downloading the remaining 2148
#  100% |████████████████| 2148/2148 [4.4m elapsed, 0s remaining, 5.5 images/s]
# Writing annotations for 8148 downloaded samples to '/home/irwan/fiftyone/coco-2017/train/labels.json'
# Dataset info written to '/home/irwan/fiftyone/coco-2017/info.json'
# Loading existing dataset 'coco-2017-train-6000'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use

# %%
session = fo.launch_app(dataset)
session.dataset = dataset
# Out:
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# #focontainer-3fbeed2c-e9c3-4938-89fa-e87523dee049 {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-3fbeed2c-e9c3-4938-89fa-e87523dee049 {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-3fbeed2c-e9c3-4938-89fa-e87523dee049:focus {
#   outline: none;
# }
# #fooverlay-3fbeed2c-e9c3-4938-89fa-e87523dee049 {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# ...

# %%
view = datasetview = (
    dataset.match_labels(filter=F("label") == "chair")
    
)
# .match_labels(filter=F("label") == "chair")
only_key = "dataset5"
classes=["chair", "dining table"]

# %%
# !export FIFTYONE_CVAT_USERNAME=irwan24
# !export FIFTYONE_CVAT_PASSWORD=Conan2406

# %%
anno_results = view.annotate(
    only_key,
    label_field="ground_truth",
    label_type="detections",
    backend="cvat",
    classes=classes,
    task_assignee="irwan24",
    url="http://localhost:8080",
    launch_editor=True,
   
)
# Out:
# Please enter your login credentials.
# You can avoid this in the future by setting your `FIFTYONE_CVAT_USERNAME` and `FIFTYONE_CVAT_PASSWORD` environment variables
# Username: irwan24
# Password: ········
# Uploading samples to CVAT...
# Launching editor at 'http://localhost:8080/tasks/32/jobs/27'...

# %%
dataset1 = foz.load_zoo_dataset(
    "coco-2017",
    split="validation",
    label_types=["detections"],
    classes=["chair", "dining table"],
    max_samples=6000,
)
# Out:
# ...
# Found annotations at '/home/irwan/fiftyone/coco-2017/raw/instances_val2017.json'
# Only found 840 (<6000) samples matching your requirements
# Sufficient images already downloaded
# Existing download of split 'validation' is sufficient
# Loading existing dataset 'coco-2017-validation-6000'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use

# %%
session1 = fo.launch_app(dataset1)
session1.dataset = dataset1
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?context=ipython&subscription=0b6514aa-fbaf-49a9-863a-e7f159c81f4d"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?context=ipython&subscription=877584d4-32e6-45b3-9ea8-7c066c6484f6"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Could not connect session, trying again in 10 seconds

# %%
view1 = datasetview = (
    dataset1.match_labels(filter=F("label") == "chair")
    
)
# .match_labels(filter=F("label") == "chair")
only_key = "dataset6"
classes=["chair", "dining table"]

# %%
anno_results1 = view1.annotate(
    only_key,
    label_field="ground_truth",
    label_type="detections",
    backend="cvat",
    classes=classes,
    task_assignee="irwan24",
    url="http://localhost:8080",
    launch_editor=True,
   
)
# Out:
# Please enter your login credentials.
# You can avoid this in the future by setting your `FIFTYONE_CVAT_USERNAME` and `FIFTYONE_CVAT_PASSWORD` environment variables
# Username: irwan24
# Password: ········
# Uploading samples to CVAT...
# Launching editor at 'http://localhost:8080/tasks/33/jobs/28'...

# %%
dataset = foz.load_zoo_dataset(
    "voc-2012",
    split="train",
    label_types=["detections"],
    classes=["person", "chair", "dining table"],
    max_samples=4000,
)



session.dataset = dataset
# Out:
# Split 'train' already downloaded
# Ignoring unsupported parameter 'label_types' for importer type <class 'fiftyone.utils.data.importers.FiftyOneImageDetectionDatasetImporter'>
# Ignoring unsupported parameter 'classes' for importer type <class 'fiftyone.utils.data.importers.FiftyOneImageDetectionDatasetImporter'>
# Loading 'voc-2012' split 'train'
#  100% |███████████████| 4000/4000 [4.8s elapsed, 0s remaining, 944.3 samples/s]
# Dataset 'voc-2012-train-4000' created
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# #focontainer-a87ec1c6-b9ad-4494-bf80-1066629bb783 {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-a87ec1c6-b9ad-4494-bf80-1066629bb783 {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
# ...

# %%
view1 = datasetview = (
    dataset.match_labels(filter=F("label") == "chair")
    
)
# .match_labels(filter=F("label") == "chair")
only_key = "tasks2"
classes=["chair", "diningtable", "person", "desk"]

# %%
anno_results = view.annotate(
    only_key,
    label_field="ground_truth",
    label_type="detections",
    backend="cvat",
    classes=classes,
    task_assignee="irwan24",
    url="http://localhost:8080",
    launch_editor=True,
   
)
# Out:
# Please enter your login credentials.
# You can avoid this in the future by setting your `FIFTYONE_CVAT_USERNAME` and `FIFTYONE_CVAT_PASSWORD` environment variables
# Username: irwan24
# Password: ········
# Uploading samples to CVAT...
# Launching editor at 'http://localhost:8080/tasks/15/jobs/10'...

# %%
dataset = foz.load_zoo_dataset(
    "coco-2014",
    split="train",
    label_types=["detections"],
    classes=["person", "chair", "dining table"],
    max_samples=4000,
)



session.dataset = dataset
# Out:
# ...
#  100% |██████|    1.9Gb/1.9Gb [5.7m elapsed, 0s remaining, 8.7Mb/s]
# Extracting annotations to '/home/irwan/fiftyone/coco-2014/raw/instances_train2014.json'
# ...
#  100% |████████████████| 4000/4000 [10.0m elapsed, 0s remaining, 7.7 images/s]
# Writing annotations for 4000 downloaded samples to '/home/irwan/fiftyone/coco-2014/train/labels.json'
# Dataset info written to '/home/irwan/fiftyone/coco-2014/info.json'
# Loading 'coco-2014' split 'train'
#  100% |███████████████| 4000/4000 [19.6s elapsed, 0s remaining, 326.8 samples/s]
# Dataset 'coco-2014-train-4000' created
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?context=ipython&subscription=866f628e-8349-4f17-99b3-3af0a5db88fb"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
view1 = datasetview = (
    dataset.match_labels(filter=F("label") == "chair")
    
)
# .match_labels(filter=F("label") == "chair")
only_key = "tasks5"
classes=["chair", "diningtable", "person"]

# %%
anno_results = view1.annotate(
    only_key,
    label_field="ground_truth",
    label_type="detections",
    backend="cvat",
    classes=classes,
    task_assignee="irwan24",
    url="http://localhost:8080",
    launch_editor=True,
   
)
# Out:
# Please enter your login credentials.
# You can avoid this in the future by setting your `FIFTYONE_CVAT_USERNAME` and `FIFTYONE_CVAT_PASSWORD` environment variables
# Username: irwan24
# Password: ········
# Uploading samples to CVAT...
# Launching editor at 'http://localhost:8080/tasks/17/jobs/12'...
